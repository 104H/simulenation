# %%
# %matplotlib inline

# %% [markdown]
# # Structural Plasticity example
#
# This example shows a simple network of two populations where structural
# plasticity is used. The network has 1000 neurons, 80% excitatory and
# 20% inhibitory. The simulation starts without any connectivity. A set of
# homeostatic rules are defined, according to which structural plasticity will
# create and delete synapses dynamically during the simulation until a desired
# level of electrical activity is reached. The model of structural plasticity
# used here corresponds to the formulation presented in [1]_.
#
# At the end of the simulation, a plot of the evolution of the connectivity
# in the network and the average calcium concentration in the neurons is created.
#
# ## References
#
# .. [1] Butz, M., and van Ooyen, A. (2013). A simple rule for dendritic spine and axonal bouton formation can
#        account for cortical reorganization after focal retinal lesions. PLoS Comput. Biol. 9 (10), e1003259.

# %% [markdown]
# First, we have import all necessary modules.

# %%
import nest
import numpy
import matplotlib.pyplot as plt
import sys

# %% [markdown]
# We define general simulation parameters

# %% [markdown]
# In this implementation of structural plasticity, neurons grow
# connection points called synaptic elements. Synapses can be created
# between compatible synaptic elements. The growth of these elements is
# guided by homeostatic rules, defined as growth curves.
# Here we specify the growth curves for synaptic elements of excitatory
# and inhibitory neurons.

# %%
class StructralPlasticityExample:

    def __init__(self):
        # simulated time (ms)
        self.t_sim = 2000.0
        # simulation step (ms).
        self.dt = 0.1
        self.number_excitatory_neurons = 800
        self.number_inhibitory_neurons = 200

        # Structural_plasticity properties
        self.update_interval = 100.0
        self.record_interval = 10.0
        # rate of background Poisson input
        self.bg_rate = 10000.0
        #self.neuron_model = 'iaf_psc_exp'

        # Excitatory synaptic elements of excitatory neurons
        self.growth_curve_e_e = {
            'growth_curve': "gaussian",
            'growth_rate': 0.0001,  # (elements/ms)
            'continuous': False,
            'eta': 0.0,  # Ca2+
            'eps': 0.05,  # Ca2+
        }

        # Inhibitory synaptic elements of excitatory neurons
        self.growth_curve_e_i = {
            'growth_curve': "gaussian",
            'growth_rate': 0.0001,  # (elements/ms)
            'continuous': False,
            'eta': 0.0,  # Ca2+
            'eps': self.growth_curve_e_e['eps'],  # Ca2+
        }

        # Excitatory synaptic elements of inhibitory neurons
        self.growth_curve_i_e = {
            'growth_curve': "gaussian",
            'growth_rate': 0.0004,  # (elements/ms)
            'continuous': False,
            'eta': 0.0,  # Ca2+
            'eps': 0.2,  # Ca2+
        }

        # Inhibitory synaptic elements of inhibitory neurons
        self.growth_curve_i_i = {
            'growth_curve': "gaussian",
            'growth_rate': 0.0001,  # (elements/ms)
            'continuous': False,
            'eta': 0.0,  # Ca2+
            'eps': self.growth_curve_i_e['eps']  # Ca2+
        }

        # Now we specify the neuron model.iaf_psc_expiaf_psc_expiaf_psc_expiaf_psc_expiaf_psc_expiaf_psc_exp
        '''
        self.model_params = {'tau_m': 10.0,  # membrane time constant (ms)
                             # excitatory synaptic time constant (ms)
                             'tau_syn_ex': 2,
                             # inhibitory synaptic time constant (ms)
                             'tau_syn_in': 0.5,
                             't_ref': 2.0,  # absolute refractory period (ms)
                             'E_L': -65.0,  # resting membrane potential (mV)
                             'V_th': -50.0,  # spike threshold (mV)
                             'C_m': 250.0,  # membrane capacitance (pF)
                             'V_reset': -65.0  # reset potential (mV)
                             }
        '''
        self.model_params = {
             'E_L': -70.,  # resting membrane potential (mV)
             'C_m': 150.0,  # membrane capacity (pF)
             'g_L': 10.0,  # leak conductance  - in combo with C_m you get tau_m = ~15 ms
             'V_reset': -70.,  # reset membrane potential after a spike (mV)
             'V_th': -55.,  # spike threshold (mV)
             'tau_syn_ex': 2.,  # exc. synaptic time constant
             'tau_syn_in': 2.,  # exc. synaptic time constant

             # initial burst + adaptation
             #"a": 2.,
             #"b": 60.,
             #'tau_w': 200.,
         }
        
        self.nodes_e = None
        self.nodes_i = None
        self.mean_ca_e = []
        self.mean_ca_i = []
        self.total_connections_e = []
        self.total_connections_i = []

        self.psc_e = 585.0
        self.psc_i = -585.0
        self.psc_ext = 6.2

    def prepare_simulation(self):
        nest.ResetKernel()
        nest.set_verbosity('M_ERROR')

        nest.resolution = self.dt

        nest.structural_plasticity_update_interval = self.update_interval

        nest.CopyModel('static_synapse', 'synapse_ex')
        nest.SetDefaults('synapse_ex', {'weight': self.psc_e, 'delay': 1.0})
        nest.CopyModel('static_synapse', 'synapse_in')
        nest.SetDefaults('synapse_in', {'weight': self.psc_i, 'delay': 1.0})
        nest.structural_plasticity_synapses = {
            'synapse_ex': {
                'synapse_model': 'synapse_ex',
                'post_synaptic_element': 'Den_ex',
                'pre_synaptic_element': 'Axon_ex'
            },
            'synapse_in': {
                'synapse_model': 'synapse_in',
                'post_synaptic_element': 'Den_in',
                'pre_synaptic_element': 'Axon_in'
            }
        }

    def create_nodes(self):
        """
        Assign growth curves to synaptic elements
        """

        synaptic_elements = {
            'Den_ex': self.growth_curve_e_e,
            'Den_in': self.growth_curve_e_i,
            'Axon_ex': self.growth_curve_e_e,
        }

        synaptic_elements_i = {
            'Den_ex': self.growth_curve_i_e,
            'Den_in': self.growth_curve_i_i,
            'Axon_in': self.growth_curve_i_i,
        }

        # aeif_cond_exp
        # iaf_psc_alpha
        self.nodes_e = nest.Create('aeif_cond_exp',
                                   self.number_excitatory_neurons)

        self.nodes_i = nest.Create('aeif_cond_exp',
                                   self.number_inhibitory_neurons)
        
        #self.nodes_e.set(self.model_params)
        #self.nodes_i.set(self.model_params)
        
        self.nodes_e.synaptic_elements = synaptic_elements
        self.nodes_i.synaptic_elements = synaptic_elements_i

    def connect_external_input(self):
        """
        We create and connect the Poisson generator for external input
        """
        noise = nest.Create('poisson_generator')
        noise.rate = self.bg_rate
        nest.Connect(noise, self.nodes_e, 'all_to_all',
                     {'weight': self.psc_ext, 'delay': 1.0})
        nest.Connect(noise, self.nodes_i, 'all_to_all',
                     {'weight': self.psc_ext, 'delay': 1.0})

    ####################################################################################
    # In order to save the amount of average calcium concentration in each
    # population through time we create the function ``record_ca``. Here we use
    # the value of `Ca` for every neuron in the network and then
    # store the average.
    def record_ca(self):
        ca_e = self.nodes_e.Ca,  # Calcium concentration
        self.mean_ca_e.append(numpy.mean(ca_e))

        ca_i = self.nodes_i.Ca,  # Calcium concentration
        self.mean_ca_i.append(numpy.mean(ca_i))

    ####################################################################################
    # In order to save the state of the connectivity in the network through time
    # we create the function ``record_connectivity``. Here we retrieve the number
    # of connected pre-synaptic elements of each neuron. The total amount of
    # excitatory connections is equal to the total amount of connected excitatory
    # pre-synaptic elements. The same applies for inhibitory connections.
    def record_connectivity(self):
        syn_elems_e = self.nodes_e.synaptic_elements
        syn_elems_i = self.nodes_i.synaptic_elements
        self.total_connections_e.append(sum(neuron['Axon_ex']['z_connected']
                                            for neuron in syn_elems_e))
        self.total_connections_i.append(sum(neuron['Axon_in']['z_connected']
                                            for neuron in syn_elems_i))

    ####################################################################################
    # We define a function to plot the recorded values
    # at the end of the simulation.
    def plot_data(self):
        fig, ax1 = plt.subplots()
        ax1.axhline(self.growth_curve_e_e['eps'],
                    linewidth=4.0, color='#9999FF')
        ax1.plot(self.mean_ca_e, 'b',
                 label='Ca Concentration Excitatory Neurons', linewidth=2.0)
        ax1.axhline(self.growth_curve_i_e['eps'],
                    linewidth=4.0, color='#FF9999')
        ax1.plot(self.mean_ca_i, 'r',
                 label='Ca Concentration Inhibitory Neurons', linewidth=2.0)
        ax1.set_ylim([0, 0.275])
        ax1.set_xlabel("Time in [s]")
        ax1.set_ylabel("Ca concentration")
        ax2 = ax1.twinx()
        ax2.plot(self.total_connections_e, 'm',
                 label='Excitatory connections', linewidth=2.0, linestyle='--')
        ax2.plot(self.total_connections_i, 'k',
                 label='Inhibitory connections', linewidth=2.0, linestyle='--')
        ax2.set_ylim([0, 2500])
        ax2.set_ylabel("Connections")
        ax1.legend(loc=1)
        ax2.legend(loc=4)
        plt.savefig('StructuralPlasticityExample.eps', format='eps')

    ####################################################################################
    # It is time to specify how we want to perform the simulation. In this
    # function we first enable structural plasticity in the network and then we
    # simulate in steps. On each step we record the calcium concentration and the
    # connectivity. At the end of the simulation, the plot of connections and
    # calcium concentration through time is generated.
    def simulate(self):
        if nest.NumProcesses() > 1:
            sys.exit("For simplicity, this example only works " +
                     "for a single process.")
        nest.EnableStructuralPlasticity()
        print("Starting simulation")
        sim_steps = numpy.arange(0, self.t_sim, self.record_interval)
        for i, step in enumerate(sim_steps):
            nest.Simulate(self.record_interval)
            self.record_ca()
            self.record_connectivity()
            if i % 20 == 0:
                print("Progress: " + str(i / 2) + "%")
        print("Simulation finished successfully")

# %%
if __name__ == '__main__':
    example = StructralPlasticityExample()
    # Prepare simulation
    example.prepare_simulation()
    example.create_nodes()
    example.connect_external_input()
    # Start simulation
    example.simulate()
    example.plot_data()
# Out:
# Starting simulation
# Progress: 0.0%
# Progress: 10.0%
# Progress: 20.0%
# Progress: 30.0%
# Progress: 40.0%
# Progress: 50.0%
# Progress: 60.0%
# Progress: 70.0%
# Progress: 80.0%
# Progress: 90.0%
# Simulation finished successfully
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# tau_syn_ex 2 <br />
# tau_syn_in 2 <br />
# E_L -70 <br />
# V_th -55 <br />
# V_reset -70 <br />

# %%
for _ in example.model_params.keys():
    print(_)
    print(example.nodes_e.get(_)[0])
# Out:
# E_L
# -70.6
# C_m
# 281.0
# g_L
# 30.0
# V_reset
# -60.0
# V_th
# -50.4
# tau_syn_ex
# 0.2
# tau_syn_in
# 2.0

# %%
example.nodes_e.synaptic_elements
# Out:
# ({'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05088882758981904,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05088882758981904,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05088882758981904,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04281783885482058,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04281783885482058,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04281783885482058,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04752968244074899,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04752968244074899,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04752968244074899,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04605741093470425,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04605741093470425,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04605741093470425,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05324396906574369,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05324396906574369,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05324396906574369,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057553303062605345,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057553303062605345,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057553303062605345,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06117992751032275,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06117992751032275,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06117992751032275,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053196974149175784,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053196974149175784,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053196974149175784,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05336846911195515,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05336846911195515,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05336846911195515,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05502837563728108,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05502837563728108,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05502837563728108,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0677943926686269,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0677943926686269,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0677943926686269,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05267775593774747,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05267775593774747,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05267775593774747,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06473635758301272,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06473635758301272,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06473635758301272,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05942044519537796,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05942044519537796,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05942044519537796,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05847238551118025,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05847238551118025,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05847238551118025,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05665916802998652,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05665916802998652,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05665916802998652,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055140072012511046,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055140072012511046,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055140072012511046,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05019390263220217,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05019390263220217,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05019390263220217,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05400318613185626,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05400318613185626,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05400318613185626,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05221095415298883,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05221095415298883,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05221095415298883,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.050712979117849485,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.050712979117849485,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.050712979117849485,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.050346874446626555,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.050346874446626555,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.050346874446626555,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05495484439831819,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05495484439831819,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05495484439831819,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05950466821431175,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05950466821431175,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05950466821431175,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05628213324908629,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05628213324908629,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05628213324908629,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06348812070416032,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06348812070416032,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06348812070416032,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.07039931327477564,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.07039931327477564,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.07039931327477564,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06744157301401782,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06744157301401782,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06744157301401782,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05705363018216622,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05705363018216622,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05705363018216622,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.045757007183623466,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.045757007183623466,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.045757007183623466,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06536474372505895,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06536474372505895,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06536474372505895,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05770094167548821,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05770094167548821,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05770094167548821,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06465700712268509,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06465700712268509,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06465700712268509,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05536238326642416,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05536238326642416,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05536238326642416,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.059219556718780195,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.059219556718780195,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.059219556718780195,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.052824845459945174,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.052824845459945174,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.052824845459945174,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06436143297552231,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06436143297552231,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06436143297552231,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04379663773072415,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04379663773072415,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04379663773072415,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05811493328952391,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05811493328952391,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05811493328952391,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.060257718871892636,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.060257718871892636,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.060257718871892636,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05371747280702755,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05371747280702755,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05371747280702755,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04939911934680994,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04939911934680994,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04939911934680994,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.059677547320664014,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.059677547320664014,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.059677547320664014,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06338966980190865,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06338966980190865,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06338966980190865,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06012573427426398,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06012573427426398,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06012573427426398,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05945997928394874,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05945997928394874,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05945997928394874,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06113633336281669,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06113633336281669,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06113633336281669,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04938887955763916,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04938887955763916,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04938887955763916,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0646812273946044,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0646812273946044,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0646812273946044,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055084059418347105,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055084059418347105,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055084059418347105,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05380921378541312,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05380921378541312,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05380921378541312,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057242200795244065,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057242200795244065,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057242200795244065,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.054178583603481933,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.054178583603481933,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.054178583603481933,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.049985778721631555,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.049985778721631555,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.049985778721631555,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05322376714692809,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05322376714692809,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05322376714692809,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05269594396195277,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05269594396195277,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05269594396195277,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04775898429933134,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04775898429933134,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04775898429933134,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06994381912228033,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06994381912228033,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06994381912228033,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06856926533333807,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06856926533333807,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06856926533333807,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0524988925586518,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0524988925586518,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0524988925586518,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05574196577365973,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05574196577365973,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05574196577365973,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04900198290475087,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04900198290475087,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04900198290475087,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.07249283078558341,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.07249283078558341,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.07249283078558341,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055983357541426366,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055983357541426366,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055983357541426366,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06905359253082281,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06905359253082281,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06905359253082281,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05688442900612063,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05688442900612063,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05688442900612063,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.043454254485831324,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.043454254485831324,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.043454254485831324,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05349276438559483,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05349276438559483,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05349276438559483,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06614850107519435,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06614850107519435,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06614850107519435,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055540728784280534,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055540728784280534,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055540728784280534,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05876724112542179,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05876724112542179,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05876724112542179,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05045899899967011,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05045899899967011,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05045899899967011,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06068045102732118,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06068045102732118,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06068045102732118,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058268672389910674,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058268672389910674,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058268672389910674,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05931780368596892,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05931780368596892,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05931780368596892,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05309328290227007,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05309328290227007,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05309328290227007,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05930426819007723,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05930426819007723,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05930426819007723,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05253424455765821,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05253424455765821,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05253424455765821,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06090795033332359,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06090795033332359,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06090795033332359,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.056224501745433496,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.056224501745433496,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.056224501745433496,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.048062135593626445,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.048062135593626445,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.048062135593626445,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06143515864220433,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06143515864220433,
#    'z_connected': 0},
# ...
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0576776364807691,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06898718608282746,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06898718608282746,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06898718608282746,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05970670646648858,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05970670646648858,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05970670646648858,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0514443965671262,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0514443965671262,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0514443965671262,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.061644683141280514,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.061644683141280514,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.061644683141280514,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.048830330392358304,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.048830330392358304,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.048830330392358304,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04958525272563709,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04958525272563709,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04958525272563709,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06251868201290411,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06251868201290411,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06251868201290411,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058572889787435016,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058572889787435016,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058572889787435016,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05991378561160359,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05991378561160359,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05991378561160359,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05697963357695584,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05697963357695584,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05697963357695584,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055644072624136974,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055644072624136974,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.055644072624136974,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053607936834926616,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053607936834926616,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053607936834926616,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05884907566365239,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05884907566365239,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05884907566365239,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04594272375229189,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04594272375229189,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.04594272375229189,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058186414077588185,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058186414077588185,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.058186414077588185,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057983903751052134,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057983903751052134,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057983903751052134,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06226104629515056,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06226104629515056,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06226104629515056,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053365384541216684,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053365384541216684,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.053365384541216684,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.051660142377236484,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.051660142377236484,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.051660142377236484,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0709905824025185,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0709905824025185,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0709905824025185,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057787054218050984,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057787054218050984,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.057787054218050984,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05543491989918443,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05543491989918443,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05543491989918443,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.051619599398546656,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.051619599398546656,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.051619599398546656,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05631010671424416,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05631010671424416,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.05631010671424416,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0658117486807587,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0658117486807587,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.0658117486807587,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06044250146064255,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06044250146064255,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.06044250146064255,
#    'z_connected': 0}},
#  {'Axon_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.052403747551383495,
#    'z_connected': 0},
#   'Den_ex': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.052403747551383495,
#    'z_connected': 0},
#   'Den_in': {'continuous': False,
#    'eps': 0.05,
#    'eta': 0.0,
#    'growth_curve': 'gaussian',
#    'growth_rate': 0.0001,
#    'tau_vacant': 0.1,
#    'z': 0.052403747551383495,
#    'z_connected': 0}})

# %%
example.nodes_e.get('V_reset')[0]
# Out:
# -70.0
